# %%
# 查看当前挂载的数据集目录, 该目录下的变更重启环境后会自动还原
# View dataset directory. 
# This directory will be recovered automatically after resetting environment. 
# !ls /home/aistudio/data

# %%
pip install pyecharts
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.1/147.1 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.0/127.0 kB 22.0 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import xlrd

# %%
data = xlrd.open_workbook("体测影响因素.xlsx")

# %%
table = data.sheets()[0]

# %%
x1=''
x1=table.col_values(0)
y1=''
y1=table.col_values(1)

# %%
from pyecharts.charts import Bar

# %%
import numpy as np

# %%
bar = ( 
    Bar()
    .add_xaxis(x1)
    .add_yaxis("体测影响因素",y1)
)

# %%
bar.render()
# Out:
# '/home/aistudio/render.html'

# %%
import matplotlib.pyplot as plt

x = ['喜欢参与体育运动','拥有两个以上的体育爱好','身体素质在平均水平','定制体育计划并予以实施']
y = [0.758,0.681,0.618,0.738]

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['可以培养社交能力','让自身心情变好','促进与朋友之间的感情','让自身身体更健康、强壮']
y = [0.682,0.617,0.633,0.706]

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['没有足够的时间','意志力不足','没有兴趣爱好','没有玩伴陪同锻炼']
y = [0.741,0.613,0.64,0.682]

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['田径类（长跑、短跑）','足球、藤球类','篮球、排球类','网球、乒乓球、羽毛球类','形体类（瑜伽、健美操、体育舞蹈、啦啦操）'
,'搏击类（跆拳道、武术、散打）']
y = [0.711,0.606,0.51,0.663,0.567,0.565]

plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['觉得上体育课是负担','喜欢体育老师的教学风格','学校的体育设施不能满足需求','学校不重视体育课程','开设运动项目种类少']
y = [0.745,0.733,0.711,0.693,0.779]

plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['扰乱了健康作息',
'线上学习繁重',
'心理/情绪较容易波动',
'疫情后的运动频率、时长比疫情前高'
]
y = [0.751,
0.671,
0.716,
0.742
]

plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['800米跑步/1000米跑步',
'50米跑步',
'仰卧起坐/引体向上',
'立定跳远',
'肺活量',
'身高/体重',
'坐位体前屈'
]
y = [0.735,
0.737,
0.714,
0.751,
0.707,
0.695,
0.745
]

plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['家庭经济收入情况低',
'父母的身体素质较差',
'家庭地理位置较偏僻',
'血型问题',
'居住地气候不适宜',
'营养情况不佳',
'先天性运动禀赋不足',
'家庭周边体育设施建设发展水平底',
]
sizes = [0.703,
0.689,
0.55,
0.65,
0.634,
0.574,
0.741,
0.671
]

plt.pie(sizes, labels=labels)
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['只会对自己有信心的项目才不会担心',
'尽自己最大的努力去取得一个较好成绩',
'很快调整自己的状态',
'在体测前我会和同学一起去操场锻炼',
'在体测时我会鼓励同学和帮助',
'体测时，我会找同学替考一些自己不擅长的项目'
]
sizes = [0.73,
0.687,
0.557,
0.764,
0.732,
0.618
]

plt.pie(sizes, labels=labels)
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['了解自身健康状况',
'提升自身体能素质',
'用作参与评价评优',
'用作毕业考核',
'帮助学生养成健身习惯',
'可以磨炼意志力的有效途径'
]
sizes = [0.695,
0.68,
0.692,
0.627,
0.668,
0.682

]

plt.pie(sizes, labels=labels)
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['认为自己很健谈',
'常常乐于助人',
'精力充沛',
'宽容大度',
'经常熬夜',
'饮食不规律',
'在空闲的时候，躺在床上不出门',
'沉迷于网络',
'我想获得新的运动技能',
'我想认识一些新的朋友',
'我想保持身心健康',
'我想提高现有的运动技能',
'我对待学习积极主动',
'我有胆量，不怕困难',
'我看到事物好的一面',
'别人不爱锻炼不会影响我是否锻炼',
'在锻炼的时候，我会尝试一些陌生的运动',
'在较强的压力下我难以保持良好的状态',
'在日常学习中，我能够及时理解老师的相关指示',
'我觉得我的运动能力能够掌握大多数运动',
'遇到误解、矛盾，和朋友及时沟通',
'生活中，我会有意营造和保持良好的组织氛围',
'我很喜欢加入组织、社团一起运动'
]
sizes = [0.772,
0.792,
0.737,
0.746,
0.757,
0.744,
0.785,
0.79,
0.725,
0.785,
0.748,
0.75,
0.782,
0.777,
0.751,
0.777,
0.782,
0.732,
0.761,
0.767,
0.776,
0.727,
0.755
]

plt.pie(sizes, labels=labels)
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['没耐心的',
'细心地',
'认真的',
'冷漠的',
'负责的',
'没有条理的',
'懒惰的',
'友好的',
'严谨的'
]
sizes = [0.699,
0.743,
0.721,
0.691,
0.698,
0.676,
0.688,
0.718,
0.733
]

plt.pie(sizes, labels=labels)
plt.show()

# %%
# 同时添加如下代码, 这样每次环境(kernel)启动的时候只要运行下方代码即可: 
# Also add the following code, 
# so that every time the environment (kernel) starts, 
# just run the following code: 
import sys 
sys.path.append('/home/aistudio/external-libraries')

# %% [markdown]
# 请点击[此处](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576)查看本环境基本用法.  <br>
# Please click [here ](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576) for more detailed instructions.
